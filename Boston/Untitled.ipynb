# %%
import pandas as pd
import numpy as np
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import mean_absolute_error
import csv
from sklearn.cross_validation import train_test_split

# %%
data = pd.read_csv('Data/train.csv')

# %%
medvMean = data.medv.mean()

# %%
a = []
for i in data.medv:
    if(i>medvMean):
        a.append("luxury")
    else:
        a.append("standard")
a
# Out:
# ['luxury',
#  'standard',
#  'luxury',
#  'luxury',
#  'luxury',
#  'standard',
#  'standard',
#  'standard',
#  'standard',
#  'standard',
#  'standard',
#  'luxury',
#  'standard',
#  'standard',
#  'standard',
#  'standard',
#  'standard',
#  'standard',
#  'standard',
#  'standard',
#  'standard',
#  'luxury',
#  'luxury',
#  'luxury',
#  'luxury',
#  'luxury',
#  'standard',
#  'standard',
#  'standard',
#  'standard',
#  'standard',
#  'standard',
#  'standard',
#  'luxury',
#  'standard',
#  'luxury',
#  'luxury',
#  'luxury',
#  'luxury',
#  'standard',
#  'standard',
#  'luxury',
#  'luxury',
#  'luxury',
#  'standard',
#  'standard',
#  'standard',
#  'luxury',
#  'luxury',
#  'luxury',
#  'luxury',
#  'standard',
#  'standard',
#  'standard',
#  'luxury',
#  'luxury',
#  'luxury',
#  'luxury',
#  'luxury',
#  'standard',
#  'standard',
#  'luxury',
#  'luxury',
#  'standard',
#  'luxury',
#  'standard',
#  'standard',
#  'luxury',
#  'luxury',
#  'standard',
# ...

# %%
data['house_type'] = a
data

data.to_csv("data2.csv")

# %%
trainRegressors = "crim,zn,indus,chas,nox,rm,age,dis,rad,tax,ptratio,black,lstat,type1".split(",")
X = data[trainRegressors]
y = data.medv

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size= .33, randomstate=17)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-27-fa930d63b75e> in <module>()
# ----> 1 X_train, X_test, y_train, y_test = train_test_split(X,y,test_size= .33, randomstate=17)
#
# /usr/local/lib/python3.6/dist-packages/sklearn/cross_validation.py in train_test_split(*arrays, **options)
#    2053
#    2054     if options:
# -> 2055         raise TypeError("Invalid parameters passed: %s" % str(options))
#    2056
#    2057     if test_size is None and train_size is None:
#
# TypeError: Invalid parameters passed: {'randomstate': 17}

# %%
nbModel.fit(X,y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-20-c708ca686c0d> in <module>()
# ----> 1 nbModel.fit(X,y)
#
# /usr/local/lib/python3.6/dist-packages/sklearn/naive_bayes.py in fit(self, X, y, sample_weight)
#     181             Returns self.
#     182         """
# --> 183         X, y = check_X_y(X, y)
#     184         return self._partial_fit(X, y, np.unique(y), _refit=True,
#     185                                  sample_weight=sample_weight)
#
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/validation.py in check_X_y(X, y, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, warn_on_dtype, estimator)
#     571     X = check_array(X, accept_sparse, dtype, order, copy, force_all_finite,
#     572                     ensure_2d, allow_nd, ensure_min_samples,
# ...
